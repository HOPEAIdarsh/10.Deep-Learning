# %%
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries
import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)

#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])

#Compiling the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

#Fitting the model
history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# 600/600 [==============================] - 3s 3ms/step - loss: 1.0904 - accuracy: 0.6314 - val_loss: 0.5021 - val_accuracy: 0.8363
# Epoch 2/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.7229 - accuracy: 0.7567 - val_loss: 0.5153 - val_accuracy: 0.8269
# Epoch 3/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.6577 - accuracy: 0.7791 - val_loss: 0.4735 - val_accuracy: 0.8472
# Epoch 4/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.6202 - accuracy: 0.7911 - val_loss: 0.4868 - val_accuracy: 0.8526
# Epoch 5/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.6020 - accuracy: 0.8005 - val_loss: 0.4307 - val_accuracy: 0.8607
# Epoch 6/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5882 - accuracy: 0.8057 - val_loss: 0.4689 - val_accuracy: 0.8590
# Epoch 7/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5718 - accuracy: 0.8105 - val_loss: 0.4661 - val_accuracy: 0.8564
# Epoch 8/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5645 - accuracy: 0.8134 - val_loss: 0.4850 - val_accuracy: 0.8663
# Epoch 9/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5568 - accuracy: 0.8168 - val_loss: 0.4327 - val_accuracy: 0.8525
# Epoch 10/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.8152 - val_loss: 0.4308 - val_accuracy: 0.8601
# Epoch 11/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.8184 - val_loss: 0.4006 - val_accuracy: 0.8678
# Epoch 12/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.8171 - val_loss: 0.4700 - val_accuracy: 0.8713
# Epoch 13/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.8202 - val_loss: 0.4297 - val_accuracy: 0.8667
# Epoch 14/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.8221 - val_loss: 0.4279 - val_accuracy: 0.8619
# Epoch 15/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5260 - accuracy: 0.8235 - val_loss: 0.3975 - val_accuracy: 0.8734
# Epoch 16/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5230 - accuracy: 0.8262 - val_loss: 0.4567 - val_accuracy: 0.8750
# Epoch 17/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.8258 - val_loss: 0.4143 - val_accuracy: 0.8669
# Epoch 18/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5190 - accuracy: 0.8258 - val_loss: 0.4548 - val_accuracy: 0.8702
# Epoch 19/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5115 - accuracy: 0.8288 - val_loss: 0.4359 - val_accuracy: 0.8739
# Epoch 20/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5088 - accuracy: 0.8291 - val_loss: 0.4922 - val_accuracy: 0.8698
# Epoch 21/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5103 - accuracy: 0.8279 - val_loss: 0.5114 - val_accuracy: 0.8715
# Epoch 22/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5210 - accuracy: 0.8259 - val_loss: 0.5157 - val_accuracy: 0.8651
# Epoch 23/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5136 - accuracy: 0.8268 - val_loss: 0.4074 - val_accuracy: 0.8718
# Epoch 24/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5117 - accuracy: 0.8280 - val_loss: 0.4475 - val_accuracy: 0.8621
# Epoch 25/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5127 - accuracy: 0.8272 - val_loss: 0.3940 - val_accuracy: 0.8737
# Epoch 26/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5020 - accuracy: 0.8303 - val_loss: 0.4033 - val_accuracy: 0.8667
# Epoch 27/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5028 - accuracy: 0.8303 - val_loss: 0.4155 - val_accuracy: 0.8689
# Epoch 28/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5051 - accuracy: 0.8283 - val_loss: 0.3866 - val_accuracy: 0.8781
# Epoch 29/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5012 - accuracy: 0.8296 - val_loss: 0.4162 - val_accuracy: 0.8673
# Epoch 30/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4966 - accuracy: 0.8320 - val_loss: 0.3871 - val_accuracy: 0.8738

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3871 - accuracy: 0.8738

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8738

# %%
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.82      1000
#            1       0.99      0.95      0.97      1000
#            2       0.81      0.76      0.78      1000
#            3       0.88      0.91      0.90      1000
#            4       0.76      0.88      0.81      1000
#            5       0.98      0.92      0.95      1000
#            6       0.76      0.56      0.64      1000
#            7       0.89      0.96      0.92      1000
#            8       0.96      0.97      0.97      1000
#            9       0.96      0.93      0.94      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.88      0.87      0.87     10000
# weighted avg       0.88      0.87      0.87     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) # Here we get the index of maximum value in the encoded vector
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)

# %%
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))

plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
